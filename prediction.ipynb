# %%
import numpy as np
import pickle
import pandas as pd

# %%
trf = pickle.load(open('Models/trf.pkl', 'rb'))
model = pickle.load(open('Models/model.pkl', 'rb'))

# %%
features = ['study_hours_per_day', 'social_media_hours', 'netflix_hours', 'part_time_job', 'attendance_percentage', 'sleep_hours', 'diet_quality', 'exercise_frequency', 'parental_education_level', 'internet_quality', 'mental_health_rating']

# %%
test_input = pd.DataFrame(np.array([1.4, 3.1, 1.3, 'No', 94.8, 8.0,'Poor', 1, 'High School', 'Poor', 1]).reshape(1, 11), columns=features)

# %%
test_input_trf = trf.transform(test_input)

# %%
model.predict(test_input_trf)
# Out:
# array([42.47276208])
