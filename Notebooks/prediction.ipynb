# %% [markdown]
# ## Import Liberies

# %%
import numpy as np
import pickle
import pandas as pd

# %% [markdown]
# ## Load model pipeline

# %%
model = pickle.load(open('../models/student_performance_linear_regression.pkl', 'rb'))

# %% [markdown]
# ## Create new feature

# %%
features = ['study_hours_per_day', 'social_media_hours', 'netflix_hours', 'part_time_job', 'attendance_percentage', 'sleep_hours', 'diet_quality', 'exercise_frequency', 'parental_education_level', 'internet_quality', 'mental_health_rating']

# %%
test_input = pd.DataFrame(np.array([6, 2, 1, 'No', 94.8, 8.0,'Fair', 5, 'Master', 'Good', 7]).reshape(1, 11), columns=features)

# %% [markdown]
# ## Prediction of new features

# %%
model.predict(test_input)[0]
# Out:
# np.float64(106.85678912489945)
